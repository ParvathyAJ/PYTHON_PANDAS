# %%
import pandas as pd

# %% [markdown]
# # Pass a URL to pd.read_csv() Method

# %%
url = "https://data.cityofnewyork.us/resource/25th-nujf.csv"
baby_names = pd.read_csv(url)
baby_names.head()
# Out:
#    brth_yr    gndr                      ethcty      nm  cnt  rnk
# 0     2019  FEMALE  ASIAN AND PACIFIC ISLANDER   Chloe  131    1
# 1     2019  FEMALE  ASIAN AND PACIFIC ISLANDER  Olivia  109    2
# 2     2019  FEMALE  ASIAN AND PACIFIC ISLANDER     Mia   88    3
# 3     2019  FEMALE  ASIAN AND PACIFIC ISLANDER  Sophia   71    4
# 4     2019  FEMALE  ASIAN AND PACIFIC ISLANDER    Emma   71    4

# %%
baby_names["nm"].to_frame()
# Out:
#            nm
# 0       Chloe
# 1      Olivia
# 2         Mia
# 3      Sophia
# 4        Emma
# ..        ...
# 995    Andrew
# 996   Ibrahim
# 997      Adam
# 998  Abdullah
# 999       Ian
#
# [1000 rows x 1 columns]

# %%
baby_names["nm"].tolist()
# Out:
# ['Chloe',
#  'Olivia',
#  'Mia',
#  'Sophia',
#  'Emma',
#  'Amelia',
#  'Charlotte',
#  'Emily',
#  'Grace',
#  'Isabella',
#  'Ella',
#  'Evelyn',
#  'Ava',
#  'Hannah',
#  'Bella',
#  'Aria',
#  'Sarah',
#  'Hailey',
#  'Arya',
#  'Claire',
#  'Fatima',
#  'Ellie',
#  'Maryam',
#  'Kayla',
#  'Zoe',
#  'Audrey',
#  'Avery',
#  'Abigail',
#  'Anna',
#  'Maya',
#  'Alyssa',
#  'Alice',
#  'Sofia',
#  'Riley',
#  'Jasmine',
#  'Zoey',
#  'Celine',
#  'Emilia',
#  'Tenzin',
#  'Inaaya',
#  'Joanna',
#  'Fiona',
#  'Alina',
#  'Sophie',
#  'Leah',
#  'Anaya',
#  'Ayesha',
#  'Luna',
#  'Zainab',
#  'Eva',
#  'Annie',
#  'Amaya',
#  'Mila',
#  'Angela',
#  'Elena',
#  'Inaya',
#  'Anabia',
#  'Ariana',
#  'Manha',
#  'Penelope',
#  'Zara',
#  'Nina',
#  'Katherine',
#  'Aliza',
#  'Scarlett',
#  'Zahra',
#  'Layla',
#  'Natalie',
#  'Eleanor',
#  'Harper',
#  'Jannatul',
#  'Irene',
#  'Kylie',
#  'Aiza',
#  'Eliana',
#  'Phoebe',
#  'Jocelyn',
#  'Sara',
#  'Ashley',
#  'Cynthia',
# ...

# %%
baby_names["nm"].to_dict()
# Out:
# {0: 'Chloe',
#  1: 'Olivia',
#  2: 'Mia',
#  3: 'Sophia',
#  4: 'Emma',
#  5: 'Amelia',
#  6: 'Charlotte',
#  7: 'Emily',
#  8: 'Grace',
#  9: 'Isabella',
#  10: 'Ella',
#  11: 'Evelyn',
#  12: 'Ava',
#  13: 'Hannah',
#  14: 'Bella',
#  15: 'Aria',
#  16: 'Sarah',
#  17: 'Hailey',
#  18: 'Arya',
#  19: 'Claire',
#  20: 'Fatima',
#  21: 'Ellie',
#  22: 'Maryam',
#  23: 'Kayla',
#  24: 'Zoe',
#  25: 'Audrey',
#  26: 'Avery',
#  27: 'Abigail',
#  28: 'Anna',
#  29: 'Maya',
#  30: 'Alyssa',
#  31: 'Alice',
#  32: 'Sofia',
#  33: 'Riley',
#  34: 'Jasmine',
#  35: 'Zoey',
#  36: 'Celine',
#  37: 'Emilia',
#  38: 'Tenzin',
#  39: 'Inaaya',
#  40: 'Joanna',
#  41: 'Fiona',
#  42: 'Alina',
#  43: 'Sophie',
#  44: 'Leah',
#  45: 'Anaya',
#  46: 'Ayesha',
#  47: 'Luna',
#  48: 'Zainab',
#  49: 'Eva',
#  50: 'Annie',
#  51: 'Amaya',
#  52: 'Mila',
#  53: 'Angela',
#  54: 'Elena',
#  55: 'Inaya',
#  56: 'Anabia',
#  57: 'Ariana',
#  58: 'Manha',
#  59: 'Penelope',
#  60: 'Zara',
#  61: 'Nina',
# ...

# %%
"!".join(["a","b","c"])
# Out:
# 'a!b!c'

# %%
", ".join(baby_names["nm"])
# Out:
# 'Chloe, Olivia, Mia, Sophia, Emma, Amelia, Charlotte, Emily, Grace, Isabella, Ella, Evelyn, Ava, Hannah, Bella, Aria, Sarah, Hailey, Arya, Claire, Fatima, Ellie, Maryam, Kayla, Zoe, Audrey, Avery, Abigail, Anna, Maya, Alyssa, Alice, Sofia, Riley, Jasmine, Zoey, Celine, Emilia, Tenzin, Inaaya, Joanna, Fiona, Alina, Sophie, Leah, Anaya, Ayesha, Luna, Zainab, Eva, Annie, Amaya, Mila, Angela, Elena, Inaya, Anabia, Ariana, Manha, Penelope, Zara, Nina, Katherine, Aliza, Scarlett, Zahra, Layla, Natalie, Eleanor, Harper, Jannatul, Irene, Kylie, Aiza, Eliana, Phoebe, Jocelyn, Sara, Ashley, Cynthia, Ariel, Jessica, Ayat, Vivian, Madeline, Angelina, Melody, Amy, Khadija, Rachel, Stella, Madison, Catherine, Abby, Julia, Nora, Michelle, Aurora, Elise, Elizabeth, Kaylee, Aleena, Ivy, Ada, Naomi, Ariella, Athena, Allison, Alexandra, Mariam, Karen, Cecilia, Iris, Isla, Daisy, Joy, Kiara, Zoya, Ophelia, Erin, Lily, Elina, Miya, Aaliyah, Kelly, Stephanie, Violet, Esther, Alisha, Ruby, Angie, Norah, Rh
# ...

# %%
", ".join(baby_names["nm"].str.title())
# Out:
# 'Chloe, Olivia, Mia, Sophia, Emma, Amelia, Charlotte, Emily, Grace, Isabella, Ella, Evelyn, Ava, Hannah, Bella, Aria, Sarah, Hailey, Arya, Claire, Fatima, Ellie, Maryam, Kayla, Zoe, Audrey, Avery, Abigail, Anna, Maya, Alyssa, Alice, Sofia, Riley, Jasmine, Zoey, Celine, Emilia, Tenzin, Inaaya, Joanna, Fiona, Alina, Sophie, Leah, Anaya, Ayesha, Luna, Zainab, Eva, Annie, Amaya, Mila, Angela, Elena, Inaya, Anabia, Ariana, Manha, Penelope, Zara, Nina, Katherine, Aliza, Scarlett, Zahra, Layla, Natalie, Eleanor, Harper, Jannatul, Irene, Kylie, Aiza, Eliana, Phoebe, Jocelyn, Sara, Ashley, Cynthia, Ariel, Jessica, Ayat, Vivian, Madeline, Angelina, Melody, Amy, Khadija, Rachel, Stella, Madison, Catherine, Abby, Julia, Nora, Michelle, Aurora, Elise, Elizabeth, Kaylee, Aleena, Ivy, Ada, Naomi, Ariella, Athena, Allison, Alexandra, Mariam, Karen, Cecilia, Iris, Isla, Daisy, Joy, Kiara, Zoya, Ophelia, Erin, Lily, Elina, Miya, Aaliyah, Kelly, Stephanie, Violet, Esther, Alisha, Ruby, Angie, Norah, Rh
# ...

# %%
", ".join(baby_names["nm"].str.title().drop_duplicates().sort_values())
# Out:
# 'Aaliyah, Aaron, Abby, Abdullah, Abigail, Ada, Adam, Addison, Adelaide, Adele, Adeline, Adelynn, Adina, Adriana, Ahuva, Aicha, Aiden, Ailani, Aileen, Aisha, Aiza, Alahia, Alaia, Alana, Alani, Alanna, Alayna, Aleah, Aleena, Alessandra, Alessia, Alexa, Alexander, Alexandra, Alexis, Alia, Alice, Alicia, Alina, Alisha, Alison, Aliya, Aliyah, Aliza, Allison, Alma, Alondra, Alyssa, Amaia, Amalia, Amanda, Amani, Amara, Amaya, Amayah, Amber, Amelia, Amelie, Amina, Aminata, Amira, Amirah, Amiyah, Amora, Amy, Ana, Anabia, Analia, Anastasia, Anaya, Andrea, Andrew, Angela, Angelica, Angelina, Angie, Aniyah, Anna, Annabel, Annabelle, Annalise, Annie, Antonella, Anya, April, Arham, Aria, Ariah, Ariana, Arianna, Ariel, Ariella, Arielle, Ariyah, Arlette, Arya, Ashley, Astrid, Athena, Aubree, Aubrey, Audrey, Aurelia, Aurora, Austin, Autumn, Ava, Avery, Aviva, Aya, Ayaan, Ayala, Ayat, Ayesha, Ayla, Ayra, Baila, Batsheva, Beatrice, Bella, Bianca, Bina, Bintou, Blair, Blake, Blima, Blimy, Bracha, Breind
# ...

# %% [markdown]
# # Export CSV

# %%
url = "https://data.cityofnewyork.us/resource/25th-nujf.csv"
baby_names = pd.read_csv(url)
baby_names.head()
# Out:
#    brth_yr    gndr                      ethcty      nm  cnt  rnk
# 0     2019  FEMALE  ASIAN AND PACIFIC ISLANDER   Chloe  131    1
# 1     2019  FEMALE  ASIAN AND PACIFIC ISLANDER  Olivia  109    2
# 2     2019  FEMALE  ASIAN AND PACIFIC ISLANDER     Mia   88    3
# 3     2019  FEMALE  ASIAN AND PACIFIC ISLANDER  Sophia   71    4
# 4     2019  FEMALE  ASIAN AND PACIFIC ISLANDER    Emma   71    4

# %%
baby_names.to_csv("NYC Baby Names.csv", index = False, columns =[ "nm","cnt"], encoding ="utf-8")
